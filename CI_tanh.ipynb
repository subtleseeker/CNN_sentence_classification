# %%
# !git clone https://github.com/yoonkim/CNN_sentence
# %cd CNN_sentence
# !ls
# Out:
# Cloning into 'CNN_sentence'...
# remote: Enumerating objects: 62, done.
# remote: Total 62 (delta 0), reused 0 (delta 0), pack-reused 62
# Unpacking objects: 100% (62/62), done.
# /content/CNN_sentence
# conv_net_classes.py   process_data.py  rt-polarity.neg
# conv_net_sentence.py  README.md        rt-polarity.pos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# "Save to my drive" these in your google drive before executing this cell
# https://drive.google.com/open?id=1YsZUoDNulojsObYbxgPRdBe2G9RfL4YP
# https://drive.google.com/open?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# https://drive.google.com/open?id=1gsd4rVWI6CfAoXWNpstc_K3wYsaNZRxg

# !cp "/content/drive/My Drive/GoogleNews-vectors-negative300.bin.gz" .
# !gunzip -k GoogleNews-vectors-negative300.bin.gz
# !rm -r GoogleNews-vectors-negative300.bin.gz

# !rm -r conv_net_classes.py
# !cp "/content/drive/My Drive/conv_net_classes.py" .

# !rm -r conv_net_sentence_tanh.py
# !cp "/content/drive/My Drive/conv_net_sentence_tanh.py" .

# !ls
# Out:
# rm: cannot remove 'conv_net_sentence_tanh.py': No such file or directory
# conv_net_classes.py	   GoogleNews-vectors-negative300.bin  rt-polarity.neg
# conv_net_sentence.py	   process_data.py		       rt-polarity.pos
# conv_net_sentence_tanh.py  README.md

# %%
# !python2 process_data.py GoogleNews-vectors-negative300.bin
# Out:
# loading data... data loaded!
# number of sentences: 10662
# vocab size: 18765
# max sentence length: 56
# loading word2vec vectors... word2vec loaded!
# num words already in word2vec: 16448
# dataset created!

# %%
# !THEANO_FLAGS=mode=FAST_RUN,device=cuda*,floatX=float32 python conv_net_sentence_tanh.py -static -word2vec
# Out:
# ERROR (theano.gpuarray): pygpu was configured but could not be imported or is too old (version 0.7 or higher required)
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/theano/gpuarray/__init__.py", line 23, in <module>
#     import pygpu
# ImportError: No module named pygpu
# loading data... data loaded!
# model architecture: CNN-static
# using: word2vec vectors
# [('image shape', 64, 300), ('filter shape', [(100, 1, 3, 300), (100, 1, 4, 300), (100, 1, 5, 300)]), ('hidden_units', [100, 2]), ('dropout', [0.5]), ('batch_size', 50), ('non_static', False), ('learn_decay', 0.95), ('conv_non_linear', 'tanh'), ('non_static', False), ('sqr_norm_lim', 9), ('shuffle_batch', True)]
# WARNING (theano.tensor.blas): We did not find a dynamic library in the library_dir of the library we use for blas. If you use ATLAS, make sure to compile it with dynamics library.
# ... training
# epoch: 1, training time: 219.43 secs, train perf: 79.72 %, val perf: 78.00 %
# epoch: 2, training time: 217.15 secs, train perf: 85.35 %, val perf: 81.37 %
# epoch: 3, training time: 212.54 secs, train perf: 86.42 %, val perf: 77.79 %
# epoch: 4, training time: 209.28 secs, train perf: 90.66 %, val perf: 80.00 %
# epoch: 5, training time: 208.56 secs, train perf: 94.92 %, val perf: 81.37 %
# epoch: 6, training time: 210.62 secs, train perf: 97.70 %, val perf: 81.58 %
# epoch: 7, training time: 209.57 secs, train perf: 96.83 %, val perf: 78.11 %
# epoch: 8, training time: 210.53 secs, train perf: 99.33 %, val perf: 81.89 %
# epoch: 9, training time: 207.69 secs, train perf: 99.69 %, val perf: 82.74 %
# epoch: 10, training time: 209.25 secs, train perf: 99.84 %, val perf: 82.74 %
# cv: 0, perf: 0.8076225045372051
# 0.8076225045372051
